# %% [markdown]
# Tuần 1- Bài 1

# %% [markdown]
# Yêu cầu:Cho biết kích thước, số chiều và kiểu dữ liệu của Tensor a.

# %% [markdown]
# Tạo tensor cho biến a với 2 chiều khích thước là a[2][3] và được lưu với kiểu dữ liệu int với 32 bit

# %%
import torch
a=torch.tensor([[1,2,3],[3,2,1]],dtype=torch.int32)
print(a)
# Out:
# tensor([[1, 2, 3],
#         [3, 2, 1]], dtype=torch.int32)
